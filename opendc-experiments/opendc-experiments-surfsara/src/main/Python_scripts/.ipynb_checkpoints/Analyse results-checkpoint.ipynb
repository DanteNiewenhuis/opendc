# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from datetime import timedelta

from IPython.display import display, HTML

import pyarrow as pa

base_folder = "../"

start_time = "2022-10-13"
end_time = "2022-10-14"

workload_name = f"surfsara/{start_time}_{end_time}"

if os.path.exists(f"{base_folder}/resources/traces/{workload_name}"):
    print("Trace folder exists")
else:
    print("ERROR: Trace folder does not exist")
    
if os.path.exists(f"{base_folder}/output/{workload_name}"):
    print("Output folder exists")
else:
    print("ERROR: Output folder does not exist")
# Out:
# Trace folder exists
# ERROR: Output folder does not exist

# %% [markdown]
# ## Topologies

# %%
def read_topology(topology_name):
    print(f"Topology name: {topology_name}")
    df = pd.read_csv(f"{base_folder}/resources/env/{topology_name}.txt", delimiter=";")
    display(HTML(df.to_html()))
    
def print_topologies():
    topologies = os.listdir(f"{base_folder}/resources/env")
    
    for topology_name in topologies:
        print(f"{topology_name = }")
        df = pd.read_csv(f"{base_folder}/resources/env/{topology_name}", delimiter=";")
        display(HTML(df.to_html()))
        
print_topologies()
# Out:
# topology_name = 'surfsara_200.txt'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ClusterID</th>
#       <th>ClusterName</th>
#       <th>Cores</th>
#       <th>Speed</th>
#       <th>Memory</th>
#       <th>numberOfHosts</th>
#       <th>memoryCapacityPerHost</th>
#       <th>coreCountPerHost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A01</td>
#       <td>A01</td>
#       <td>4464</td>
#       <td>0.05</td>
#       <td>27900</td>
#       <td>279</td>
#       <td>100</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# topology_name = 'multi.txt'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ClusterID</th>
#       <th>ClusterName</th>
#       <th>Cores</th>
#       <th>Speed</th>
#       <th>Memory</th>
#       <th>numberOfHosts</th>
#       <th>memoryCapacityPerHost</th>
#       <th>coreCountPerHost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A01</td>
#       <td>A01</td>
#       <td>32</td>
#       <td>3.20</td>
#       <td>2048</td>
#       <td>1</td>
#       <td>256</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>B01</td>
#       <td>B01</td>
#       <td>48</td>
#       <td>2.93</td>
#       <td>1256</td>
#       <td>6</td>
#       <td>64</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C01</td>
#       <td>C01</td>
#       <td>32</td>
#       <td>3.20</td>
#       <td>2048</td>
#       <td>2</td>
#       <td>128</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# topology_name = 'surfsara_155.txt'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ClusterID</th>
#       <th>ClusterName</th>
#       <th>Cores</th>
#       <th>Speed</th>
#       <th>Memory</th>
#       <th>numberOfHosts</th>
#       <th>memoryCapacityPerHost</th>
#       <th>coreCountPerHost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A01</td>
#       <td>A01</td>
#       <td>2480</td>
#       <td>0.00625</td>
#       <td>15500</td>
#       <td>155</td>
#       <td>100</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# topology_name = 'surfsara_279.txt'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ClusterID</th>
#       <th>ClusterName</th>
#       <th>Cores</th>
#       <th>Speed</th>
#       <th>Memory</th>
#       <th>numberOfHosts</th>
#       <th>memoryCapacityPerHost</th>
#       <th>coreCountPerHost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A01</td>
#       <td>A01</td>
#       <td>4464</td>
#       <td>0.0125</td>
#       <td>27900</td>
#       <td>279</td>
#       <td>100</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# topology_name = 'single.txt'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ClusterID</th>
#       <th>ClusterName</th>
#       <th>Cores</th>
#       <th>Speed</th>
#       <th>Memory</th>
#       <th>numberOfHosts</th>
#       <th>memoryCapacityPerHost</th>
#       <th>coreCountPerHost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A01</td>
#       <td>A01</td>
#       <td>8</td>
#       <td>3.2</td>
#       <td>128</td>
#       <td>1</td>
#       <td>128</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Traces

# %%
df_trace = pd.read_parquet(f"{base_folder}/resources/traces/{workload_name}/trace.parquet")
df_trace.head()
# Out:
# Timestamp('2022-10-12 22:00:00')

# %%
df_meta =  pd.read_parquet(f"{base_folder}/resources/traces/{workload_name}/meta.parquet")
df_meta.head()
# Out:
#         id          start_time           stop_time  cpu_count  cpu_capacity  \
# 0  2162961 2022-10-12 22:00:00 2022-10-13 02:11:31         16       10000.0
# 1  2169697 2022-10-12 22:00:00 2022-10-13 22:00:00         16       10000.0
# 2  2173909 2022-10-12 22:00:00 2022-10-13 22:00:00         16       10000.0
# 3  2173910 2022-10-12 22:00:00 2022-10-13 22:00:00         16       10000.0
# 4  2173911 2022-10-12 22:00:00 2022-10-13 22:00:00         16       10000.0
#
#    mem_capacity
# 0        100000
# 1        100000
# 2        100000
# 3        100000
# 4        100000

# %%
df_energy =  pd.read_parquet(f"{base_folder}/resources/traces/{workload_name}/energy.parquet")
numHosts = len(df_energy.prom_node.unique())
print(numHosts)

df_energy.head()
# Out:
# 189
#                   timestamp prom_node  surfsara_power_usage  energy
# 0 2022-10-13 05:05:30+02:00    r27n18                  44.0  1320.0
# 1 2022-10-13 05:06:30+02:00    r27n18                  44.0  1320.0
# 2 2022-10-13 05:07:00+02:00    r27n18                  44.0  1320.0
# 3 2022-10-13 05:07:30+02:00    r27n18                  44.0  1320.0
# 4 2022-10-13 05:08:00+02:00    r27n18                  44.0  1320.0

# %%
def create_topology(numHosts):
    speed = 0.05
    coresPerHost = 16
    memoryCapacity = 100
    
    with open(f"{base_folder}/resources/env/surfsara_{numHosts}.txt", "w") as wf:
        wf.write("ClusterID;ClusterName;Cores;Speed;Memory;numberOfHosts;memoryCapacityPerHost;coreCountPerHost\n")
        wf.write(f"A01;A01;{coresPerHost*numHosts};{speed};{numHosts*memoryCapacity};{numHosts};{memoryCapacity};{coresPerHost}")

create_topology(numHosts)

# %% [markdown]
# # Lets run this in OpenDC!

# %% [markdown]
# ## Resulting Files

# %%
output_folder = f"{base_folder}/output"
workload = "workload=surfsara"
setup = f"surfsara_{numHosts}_0"

df_host = pd.read_parquet(f"{output_folder}/{workload_name}/{setup}/host.parquet")
df_server = pd.read_parquet(f"{output_folder}/{workload_name}/{setup}/server.parquet")
df_service = pd.read_parquet(f"{output_folder}/{workload_name}/{setup}/service.parquet")

def add_absolute_timestamp(df, start_dt):
    df["absolute_timestamp"] = start_dt + (df["timestamp"] - df["timestamp"].min())

add_absolute_timestamp(df_host, df_meta["start_time"].min())
add_absolute_timestamp(df_server, df_meta["start_time"].min())
add_absolute_timestamp(df_service, df_meta["start_time"].min())

df_host["real_timestamp"] = df_host["timestamp"] - df_host["timestamp"].min()
df_trace["real_timestamp"] = df_trace["timestamp"] - df_trace["timestamp"].min()
df_energy["real_timestamp"] = df_energy["timestamp"] - df_energy["timestamp"].min()

# %%
plt.figure(figsize=(15,5))

plt.plot(df_trace.groupby("real_timestamp").agg({"cpu_usage": "sum"}), label="data")
plt.plot(df_host.groupby("real_timestamp").agg({"cpu_usage": "sum"}), label="Opendc")

plt.title("cpu usage of two topologies")
plt.legend()
plt.ylim([0, None])

plt.show()

# %%
def my_sum(serie):
    idle_power = 1200
    idle_hosts = numHosts - len(serie)
    
    return idle_hosts * idle_power + sum(serie)

# %%
len(df_energy[df_energy.timestamp == df_energy.timestamp.min()])
# Out:
# 161

# %%
df_host[df_host.timestamp == df_host.timestamp.min()].uptime.value_counts()
# Out:
# 30000    189
# Name: uptime, dtype: int64

# %%
df_server[df_server.timestamp == "1970-01-01 00:01:00+00:00"]
# Out:
#                     timestamp                             server_id  \
# 158 1970-01-01 00:01:00+00:00  00000000-0000-0000-06c4-5d188009454f
# 159 1970-01-01 00:01:00+00:00  00000000-0000-0000-1b39-896a51a8749b
# 160 1970-01-01 00:01:00+00:00  00000000-0000-0000-2c82-9abe1f4532e1
# 161 1970-01-01 00:01:00+00:00  00000000-0000-0000-3ee5-789041c98ac3
# 162 1970-01-01 00:01:00+00:00  00000000-0000-0000-657e-ecdd3cb13d09
# ..                        ...                                   ...
# 311 1970-01-01 00:01:00+00:00  00000000-0000-7918-8617-31f13c272113
# 312 1970-01-01 00:01:00+00:00  00000000-0000-9088-58dc-98d3a4b965df
# 313 1970-01-01 00:01:00+00:00  00000000-0000-a410-717d-1b34d0f226b5
# 314 1970-01-01 00:01:00+00:00  00000000-0000-afc8-6595-5f41cfd0e893
# 315 1970-01-01 00:01:00+00:00  00000000-0000-cb20-530b-98a49018d298
#
#     server_name                               host_id  mem_capacity  \
# 158     2162961  e220a839-7b1d-cdaf-0000-000000000000           100
# 159     2169697  6e789e6a-a1b9-65f4-0000-000000000001           100
# 160     2173909  06c45d18-8009-454f-0000-000000000002           100
# 161     2173910  f88bb8a8-724c-81ec-0000-000000000003           100
# 162     2173911  1b39896a-51a8-749b-0000-000000000004           100
# ..          ...                                   ...           ...
# 311     2162327  134f7096-9181-75ce-0000-000000000029           100
# 312     2162328  12c015a9-7019-e937-0000-00000000002b           100
# 313     2162329  3e84ecb1-763e-79ad-0000-00000000002e           100
# 314     2162330  690ed476-743a-ae49-0000-00000000002f           100
# 315     2162331  774615d7-b1a1-f2e1-0000-000000000030           100
#
#      cpu_count  cpu_limit  cpu_time_active  cpu_time_idle  cpu_time_steal  \
# 158         16      800.0                0              2               0
# 159         16      800.0                0              2               0
# 160         16      800.0                0              2               0
# 161         16      800.0                0              2               0
# 162         16      800.0                0              2               0
# ..         ...        ...              ...            ...             ...
# 311         16      800.0                0              1               0
# 312         16      800.0                0              1               0
# 313         16      800.0                0              1               0
# 314         16      800.0                0              0               0
# 315         16      800.0                0              0               0
#
#      cpu_time_lost  uptime  downtime            provision_time  \
# 158              0   30000         0 1970-01-01 00:00:00+00:00
# 159              0   30000         0 1970-01-01 00:00:00+00:00
# 160              0   30000         0 1970-01-01 00:00:00+00:00
# 161              0   30000         0 1970-01-01 00:00:00+00:00
# 162              0   30000         0 1970-01-01 00:00:00+00:00
# ..             ...     ...       ...                       ...
# 311              0   29000         0 1970-01-01 00:00:31+00:00
# 312              0   23000         0 1970-01-01 00:00:37+00:00
# 313              0   18000         0 1970-01-01 00:00:42+00:00
# 314              0   15000         0 1970-01-01 00:00:45+00:00
# 315              0    8000         0 1970-01-01 00:00:52+00:00
#
#                     boot_time  absolute_timestamp
# 158 1970-01-01 00:00:00+00:00 2022-10-12 22:00:30
# 159 1970-01-01 00:00:00+00:00 2022-10-12 22:00:30
# 160 1970-01-01 00:00:00+00:00 2022-10-12 22:00:30
# 161 1970-01-01 00:00:00+00:00 2022-10-12 22:00:30
# 162 1970-01-01 00:00:00+00:00 2022-10-12 22:00:30
# ..                        ...                 ...
# 311 1970-01-01 00:00:31+00:00 2022-10-12 22:00:30
# 312 1970-01-01 00:00:37+00:00 2022-10-12 22:00:30
# 313 1970-01-01 00:00:42+00:00 2022-10-12 22:00:30
# 314 1970-01-01 00:00:45+00:00 2022-10-12 22:00:30
# 315 1970-01-01 00:00:52+00:00 2022-10-12 22:00:30
#
# [158 rows x 16 columns]

# %%
df_service.head()
# Out:
#                   timestamp  hosts_up  hosts_down  servers_pending  \
# 0 1970-01-01 00:00:30+00:00       189           0                0
# 1 1970-01-01 00:01:00+00:00       189           0                0
# 2 1970-01-01 00:01:30+00:00       189           0                0
# 3 1970-01-01 00:02:00+00:00       189           0                0
# 4 1970-01-01 00:02:30+00:00       189           0                0
#
#    servers_active  attempts_success  attempts_failure  attempts_error  \
# 0             158               168                 0               0
# 1             158               174                 0               0
# 2             156               182                 0               0
# 3             159               189                 0               0
# 4             160               200                 0               0
#
#    absolute_timestamp
# 0 2022-10-12 22:00:00
# 1 2022-10-12 22:00:30
# 2 2022-10-12 22:01:00
# 3 2022-10-12 22:01:30
# 4 2022-10-12 22:02:00

# %%
len(df_trace[df_trace.timestamp <= "2022-10-12 22:01:00"].id.unique())
# Out:
# 174

# %%
df_timed = df_server[df_server.timestamp <= "2022-10-12 22:01:00"]

df_timed.head
# Out:
# <bound method NDFrame.head of                        timestamp                             server_id  \
# 0      1970-01-01 00:00:30+00:00  00000000-0000-0000-06c4-5d188009454f
# 1      1970-01-01 00:00:30+00:00  00000000-0000-0000-1b39-896a51a8749b
# 2      1970-01-01 00:00:30+00:00  00000000-0000-0000-2c82-9abe1f4532e1
# 3      1970-01-01 00:00:30+00:00  00000000-0000-0000-3ee5-789041c98ac3
# 4      1970-01-01 00:00:30+00:00  00000000-0000-0000-657e-ecdd3cb13d09
# ...                          ...                                   ...
# 325577 1970-01-02 00:00:00+00:00  00000000-04b7-f260-03df-9ec472ee2938
# 325578 1970-01-02 00:00:00+00:00  00000000-04b7-f260-25b0-dd4a57fb574e
# 325579 1970-01-02 00:00:00+00:00  00000000-04bc-3ff0-fee4-788065b2dbf4
# 325580 1970-01-02 00:00:00+00:00  00000000-0520-c268-d77b-74fce10b2c8c
# 325581 1970-01-02 00:00:00+00:00  00000000-0526-4490-aa93-49f6301abe11
#
#        server_name                               host_id  mem_capacity  \
# 0          2162961  e220a839-7b1d-cdaf-0000-000000000000           100
# 1          2169697  6e789e6a-a1b9-65f4-0000-000000000001           100
# 2          2173909  06c45d18-8009-454f-0000-000000000002           100
# 3          2173910  f88bb8a8-724c-81ec-0000-000000000003           100
# 4          2173911  1b39896a-51a8-749b-0000-000000000004           100
# ...            ...                                   ...           ...
# 325577     2166702  4fa9fa73-2485-1729-0000-000000000027           100
# 325578     2166703  07dc930b-3022-78a8-0000-00000000002a           100
# 325579     2166705  8621a03f-e0bb-db7b-0000-00000000000c           100
# 325580     2169051  3ee57890-41c9-8ac3-0000-000000000008           100
# 325581     2166708  e220a839-7b1d-cdaf-0000-000000000000           100
#
#         cpu_count  cpu_limit  cpu_time_active  cpu_time_idle  cpu_time_steal  \
# 0              16      800.0                0              1               0
# 1              16      800.0                0              1               0
# 2              16      800.0                0              1               0
# 3              16      800.0                0              1               0
# 4              16      800.0                0              1               0
# ...           ...        ...              ...            ...             ...
# 325577         16      800.0                0              2               0
# 325578         16      800.0                0              2               0
# 325579         16      800.0                0              1               0
# 325580         16      800.0                0              1               0
# 325581         16      800.0                0              0               0
#
#         cpu_time_lost  uptime  downtime            provision_time  \
# 0                   0   30000         0 1970-01-01 00:00:00+00:00
# 1                   0   30000         0 1970-01-01 00:00:00+00:00
# 2                   0   30000         0 1970-01-01 00:00:00+00:00
# 3                   0   30000         0 1970-01-01 00:00:00+00:00
# 4                   0   30000         0 1970-01-01 00:00:00+00:00
# ...               ...     ...       ...                       ...
# 325577              0   30000         0 1970-01-01 21:59:24+00:00
# 325578              0   30000         0 1970-01-01 21:59:24+00:00
# 325579              0   30000         0 1970-01-01 22:04:06+00:00
# 325580              0   30000         0 1970-01-01 23:53:53+00:00
# 325581              0    6000         0 1970-01-01 23:59:54+00:00
#
#                        boot_time  absolute_timestamp
# 0      1970-01-01 00:00:00+00:00 2022-10-12 22:00:00
# 1      1970-01-01 00:00:00+00:00 2022-10-12 22:00:00
# 2      1970-01-01 00:00:00+00:00 2022-10-12 22:00:00
# 3      1970-01-01 00:00:00+00:00 2022-10-12 22:00:00
# 4      1970-01-01 00:00:00+00:00 2022-10-12 22:00:00
# ...                          ...                 ...
# 325577 1970-01-01 21:59:24+00:00 2022-10-13 21:59:30
# 325578 1970-01-01 21:59:24+00:00 2022-10-13 21:59:30
# 325579 1970-01-01 22:04:06+00:00 2022-10-13 21:59:30
# 325580 1970-01-01 23:53:53+00:00 2022-10-13 21:59:30
# 325581 1970-01-01 23:59:54+00:00 2022-10-13 21:59:30
#
# [325582 rows x 16 columns]>

# %%
min_power = 45*30
max_power = 350*30

def power_model(utilization):
    power_diff = max_power - min_power
    weighted_utilization = utilization**(1/(3.7))
    
    return (min_power + (power_diff * weighted_utilization)).real

df_host["energy"] = df_host["cpu_utilization"].apply(power_model).round(2)


plt.figure(figsize=(15,5))
plt.plot(df_energy.groupby("real_timestamp").agg({"energy": my_sum}), label="data")
plt.plot(df_host.groupby("real_timestamp").agg({"energy": "sum"}), label="openDC")

plt.legend()
plt.show()

# %%
data = df_power.groupby("real_timestamp").agg({"energy": my_sum})
data = data[1:].to_numpy().reshape(-1)
# Out:
# array([ 2752.73,   517.63,  2453.1 , ..., 48014.59, 49141.47, 50014.01])

# %%
def power_model(utilization, min_power, max_power, coefficient):
    power_diff = max_power - min_power
    weighted_utilization = utilization**(coefficient)
    
    return (min_power + (power_diff * weighted_utilization)).real

def mse(data, opendc):
    return ((data - opendc)**2).sum() / len(data) / data.sum()


def calc_fit(min_power, max_power, coefficient):
    df_host["energy"] = df_host["cpu_utilization"].apply(power_model, 
                                                         min_power=min_power, 
                                                         max_power=max_power, 
                                                         coefficient=coefficient).round(2)

    opendc = df_host.groupby("real_timestamp").agg({"energy": "sum"}).to_numpy().reshape(-1)

    return mse(data, opendc)

# %%
min_power = 40*30
max_power = 290*30
coefficient = 1/(3.7)

print(calc_fit(min_power, max_power, coefficient))
# Out:
# 0.17329248696672422

# %%
sum((data - opendc)**2)/len(data) / data.sum()
# Out:
# 0.17329248696672422

# %%
(opendc - data).shape
# Out:
# (2880,)
